# %%
f = open("bag_rules_day7.txt", "r")
line = f.readline()

data = []
result = []
data_full = []
all_bags_inside = 0

def bag_identify(string):
    # Gotta get them variables set up
    amounts = []
    list_str2 = []
    
    contain = string.find("contain")
    original_bag = string[0:contain-2]
    bags_contained = string[contain+8:]
    string1 = string[contain+8:-2]
    list_str = string1.split(',')
    
    # Get bag colors, in a list with strings.
    for str in list_str:
        for i in str:
            if i.isdigit():
                u = str.find(i)
                str = str[u+2:]
                
                # does bag end with ("s")? Remove it.
                if str[len(str)-1] == "s":
                    str = str[:len(str)-1]
                list_str2.append(str)
                
    # Get the amounts of bags, in a list with integers.
    for i in string:
        if i.isdigit():
            amounts.append(int(i))
            
    #DEBUG:
    #print(f"The line is {line}")   
    #print(f"The original bag is: {original_bag}")
    #print(f"The numbers/amounts are: {amounts}")
    #print(f"The contained bags are: {list_str2}")
    
    # database
    return original_bag, list_str2, amounts

def bag_contains_goal(databs, goal, bag):
    containments_of_bag = databs[databs.index(bag)+1]
    if goal in containments_of_bag:
        return "true"
    
def data_relation(databs, goal): # aka part 1
    print(f"Starting data relation calculations, to find out how many bags contain a {goal}, for {len(databs)/2} families.")
    containment = []
    for bag in databs:
        if type(bag) == str:
            # 1 So, the bag is a main bag.
            # 2 Here I check wether the bag contains the -goal- (bag_contains_goal) CHECK
            # 3 if yes, add -bag- to list -result- CHECK
            # 4 if not, go thru bag's containment. 
            # 5 check for them if they contain a gold bag.
            # 6 if they can, add -bag- to list -result.
            # 7 if they can't, repeat from line 4 for bag = bag_contains
            # repeat.
            if bag_contains_goal(databs, goal, bag) == "true":
                result.append(bag)
            else:
                for containment1 in (data[data.index(bag)+1]):
                    if bag_contains_goal(databs, goal, containment1) == "true":
                        result.append(bag)
                    else:
                        for containment2 in (data[data.index(containment1)+1]):
                            if bag_contains_goal(databs, goal, containment2) == "true":
                                result.append(bag)
                            else:
                                for containment3 in (data[data.index(containment2)+1]):
                                    if bag_contains_goal(databs, goal, containment3) == "true":
                                        result.append(bag)
                                    else:
                                        for containment4 in (data[data.index(containment3)+1]):
                                            if bag_contains_goal(databs, goal, containment4) == "true":
                                                result.append(bag)
                                            else:
                                                for containment5 in (data[data.index(containment4)+1]):
                                                    if bag_contains_goal(databs, goal, containment5) == "true":
                                                        result.append(bag)
                                                    else:
                                                        for containment6 in (data[data.index(containment5)+1]):
                                                            if bag_contains_goal(databs, goal, containment6) == "true":
                                                                result.append(bag)
                                                            else:
                                                                for containment7 in (data[data.index(containment6)+1]):
                                                                    if bag_contains_goal(databs, goal, containment7) == "true":
                                                                        result.append(bag)
                    
    return result

def bags_inside(mBag, data, multi): # Part 2
    # How many individual bags are required inside your single shiny gold bag?
    global all_bags_inside
    if data[0] == mBag:
        children = data[1]
        amount_of_children = data[2]
        all_bags_inside += sum(amount_of_children)*multi
        for i in children:
            p = children.index(i)
            m = multi * amount_of_children[p]
            c = data_full.index(i)
            new_data = data_full[c:c+3]
            bags_inside(i, new_data,m)

# The file handling
while line:
    x = bag_identify(line)
    data_full += x
    x = x[:2]
    data += x
    line = f.readline()

z = open("bag_rules_day7.txt", "r")
line2 = z.readline()
while line2:
    p = bag_identify(line2)
    c = bags_inside('shiny gold bag', p, 1)
    line2 = z.readline()

    
# OUTPUT
print(f"Starting to count all bags inside a 'shiny gold bag', for 570 families.")
print(f"The bags have been identified, split into {len(data)} datapoints.")
#answer1 = data_relation(data, 'shiny gold bag')
#answer1 = list(dict.fromkeys(answer1))
print(f"The amount of bags with a shiny gold bag inside, is {len(answer1)}!")
print(f"The amount of bags required inside a shiny gold bag is {answer2}")
# Out:
# Data is: ('shiny gold bag', ['muted olive bag', 'dotted red bag', 'drab plum bag'], [1, 5, 1])
# Children are: ['muted olive bag', 'dotted red bag', 'drab plum bag']
# Amount is: [1, 5, 1]
# Total bags inside : 7
# New data is ['muted olive bag', ['clear blue bag', 'posh lavender bag', 'posh brown bag', 'striped chartreuse bag'], [4, 1, 1, 2]]
# Data is: ['muted olive bag', ['clear blue bag', 'posh lavender bag', 'posh brown bag', 'striped chartreuse bag'], [4, 1, 1, 2]]
# Children are: ['clear blue bag', 'posh lavender bag', 'posh brown bag', 'striped chartreuse bag']
# Amount is: [4, 1, 1, 2]
# Total bags inside : 15
# New data is ['clear blue bag', [], []]
# Data is: ['clear blue bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 15
# New data is ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Data is: ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Children are: ['bright red bag', 'shiny lime bag', 'bright chartreuse bag']
# Amount is: [3, 2, 2]
# Total bags inside : 22
# New data is ['bright red bag', [], []]
# Data is: ['bright red bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 22
# New data is ['shiny lime bag', [], []]
# Data is: ['shiny lime bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 22
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 22
# New data is ['posh brown bag', ['dull cyan bag'], [3]]
# Data is: ['posh brown bag', ['dull cyan bag'], [3]]
# Children are: ['dull cyan bag']
# Amount is: [3]
# Total bags inside : 25
# New data is ['dull cyan bag', [], []]
# Data is: ['dull cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 25
# New data is ['striped chartreuse bag', ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag'], [4, 1, 2]]
# Data is: ['striped chartreuse bag', ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag'], [4, 1, 2]]
# Children are: ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag']
# Amount is: [4, 1, 2]
# Total bags inside : 39
# New data is ['posh black bag', [], []]
# Data is: ['posh black bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 39
# New data is ['vibrant cyan bag', [], []]
# Data is: ['vibrant cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 39
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 39
# New data is ['dotted red bag', ['muted olive bag', 'posh lavender bag', 'faded maroon bag', 'bright tomato bag'], [5, 1, 2, 3]]
# Data is: ['dotted red bag', ['muted olive bag', 'posh lavender bag', 'faded maroon bag', 'bright tomato bag'], [5, 1, 2, 3]]
# Children are: ['muted olive bag', 'posh lavender bag', 'faded maroon bag', 'bright tomato bag']
# Amount is: [5, 1, 2, 3]
# Total bags inside : 94
# New data is ['muted olive bag', ['clear blue bag', 'posh lavender bag', 'posh brown bag', 'striped chartreuse bag'], [4, 1, 1, 2]]
# Data is: ['muted olive bag', ['clear blue bag', 'posh lavender bag', 'posh brown bag', 'striped chartreuse bag'], [4, 1, 1, 2]]
# Children are: ['clear blue bag', 'posh lavender bag', 'posh brown bag', 'striped chartreuse bag']
# Amount is: [4, 1, 1, 2]
# Total bags inside : 294
# New data is ['clear blue bag', [], []]
# Data is: ['clear blue bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 294
# New data is ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Data is: ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Children are: ['bright red bag', 'shiny lime bag', 'bright chartreuse bag']
# Amount is: [3, 2, 2]
# Total bags inside : 469
# New data is ['bright red bag', [], []]
# Data is: ['bright red bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 469
# New data is ['shiny lime bag', [], []]
# Data is: ['shiny lime bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 469
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 469
# New data is ['posh brown bag', ['dull cyan bag'], [3]]
# Data is: ['posh brown bag', ['dull cyan bag'], [3]]
# Children are: ['dull cyan bag']
# Amount is: [3]
# Total bags inside : 544
# New data is ['dull cyan bag', [], []]
# Data is: ['dull cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 544
# New data is ['striped chartreuse bag', ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag'], [4, 1, 2]]
# Data is: ['striped chartreuse bag', ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag'], [4, 1, 2]]
# Children are: ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag']
# Amount is: [4, 1, 2]
# Total bags inside : 894
# New data is ['posh black bag', [], []]
# Data is: ['posh black bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 894
# New data is ['vibrant cyan bag', [], []]
# Data is: ['vibrant cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 894
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 894
# New data is ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Data is: ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Children are: ['bright red bag', 'shiny lime bag', 'bright chartreuse bag']
# Amount is: [3, 2, 2]
# Total bags inside : 929
# New data is ['bright red bag', [], []]
# Data is: ['bright red bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 929
# New data is ['shiny lime bag', [], []]
# Data is: ['shiny lime bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 929
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 929
# New data is ['faded maroon bag', ['dull lime bag', 'plaid black bag', 'drab beige bag', 'clear gray bag'], [5, 1, 5, 5]]
# Data is: ['faded maroon bag', ['dull lime bag', 'plaid black bag', 'drab beige bag', 'clear gray bag'], [5, 1, 5, 5]]
# Children are: ['dull lime bag', 'plaid black bag', 'drab beige bag', 'clear gray bag']
# Amount is: [5, 1, 5, 5]
# Total bags inside : 1089
# New data is ['dull lime bag', ['dotted violet bag', 'vibrant cyan bag'], [2, 3]]
# Data is: ['dull lime bag', ['dotted violet bag', 'vibrant cyan bag'], [2, 3]]
# Children are: ['dotted violet bag', 'vibrant cyan bag']
# Amount is: [2, 3]
# Total bags inside : 1339
# New data is ['dotted violet bag', ['light silver bag'], [4]]
# Data is: ['dotted violet bag', ['light silver bag'], [4]]
# Children are: ['light silver bag']
# Amount is: [4]
# Total bags inside : 1739
# New data is ['light silver bag', [], []]
# Data is: ['light silver bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 1739
# New data is ['vibrant cyan bag', [], []]
# Data is: ['vibrant cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 1739
# New data is ['plaid black bag', ['dark green bag', 'bright fuchsia bag', 'shiny lime bag'], [5, 4, 2]]
# Data is: ['plaid black bag', ['dark green bag', 'bright fuchsia bag', 'shiny lime bag'], [5, 4, 2]]
# Children are: ['dark green bag', 'bright fuchsia bag', 'shiny lime bag']
# Amount is: [5, 4, 2]
# Total bags inside : 1849
# New data is ['dark green bag', ['posh black bag', 'striped fuchsia bag'], [1, 3]]
# Data is: ['dark green bag', ['posh black bag', 'striped fuchsia bag'], [1, 3]]
# Children are: ['posh black bag', 'striped fuchsia bag']
# Amount is: [1, 3]
# Total bags inside : 2049
# New data is ['posh black bag', [], []]
# Data is: ['posh black bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 2049
# New data is ['striped fuchsia bag', ['posh lavender bag', 'dull cyan bag', 'posh black bag', 'vibrant bronze bag'], [4, 5, 2, 2]]
# Data is: ['striped fuchsia bag', ['posh lavender bag', 'dull cyan bag', 'posh black bag', 'vibrant bronze bag'], [4, 5, 2, 2]]
# Children are: ['posh lavender bag', 'dull cyan bag', 'posh black bag', 'vibrant bronze bag']
# Amount is: [4, 5, 2, 2]
# Total bags inside : 3999
# New data is ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Data is: ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Children are: ['bright red bag', 'shiny lime bag', 'bright chartreuse bag']
# Amount is: [3, 2, 2]
# Total bags inside : 8199
# New data is ['bright red bag', [], []]
# Data is: ['bright red bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 8199
# New data is ['shiny lime bag', [], []]
# Data is: ['shiny lime bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 8199
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 8199
# New data is ['dull cyan bag', [], []]
# Data is: ['dull cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 8199
# New data is ['posh black bag', [], []]
# Data is: ['posh black bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 8199
# New data is ['vibrant bronze bag', ['clear blue bag'], [5]]
# Data is: ['vibrant bronze bag', ['clear blue bag'], [5]]
# Children are: ['clear blue bag']
# Amount is: [5]
# Total bags inside : 9699
# New data is ['clear blue bag', [], []]
# Data is: ['clear blue bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 9699
# New data is ['bright fuchsia bag', ['shiny chartreuse bag', 'vibrant bronze bag'], [3, 5]]
# Data is: ['bright fuchsia bag', ['shiny chartreuse bag', 'vibrant bronze bag'], [3, 5]]
# Children are: ['shiny chartreuse bag', 'vibrant bronze bag']
# Amount is: [3, 5]
# Total bags inside : 10019
# New data is ['shiny chartreuse bag', ['posh black bag', 'clear blue bag'], [5, 1]]
# Data is: ['shiny chartreuse bag', ['posh black bag', 'clear blue bag'], [5, 1]]
# Children are: ['posh black bag', 'clear blue bag']
# Amount is: [5, 1]
# Total bags inside : 10739
# New data is ['posh black bag', [], []]
# Data is: ['posh black bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 10739
# New data is ['clear blue bag', [], []]
# Data is: ['clear blue bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 10739
# New data is ['vibrant bronze bag', ['clear blue bag'], [5]]
# Data is: ['vibrant bronze bag', ['clear blue bag'], [5]]
# Children are: ['clear blue bag']
# Amount is: [5]
# Total bags inside : 11739
# New data is ['clear blue bag', [], []]
# Data is: ['clear blue bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 11739
# New data is ['shiny lime bag', [], []]
# Data is: ['shiny lime bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 11739
# New data is ['drab beige bag', ['dark green bag', 'bright maroon bag'], [2, 2]]
# Data is: ['drab beige bag', ['dark green bag', 'bright maroon bag'], [2, 2]]
# Children are: ['dark green bag', 'bright maroon bag']
# Amount is: [2, 2]
# Total bags inside : 11939
# New data is ['dark green bag', ['posh black bag', 'striped fuchsia bag'], [1, 3]]
# Data is: ['dark green bag', ['posh black bag', 'striped fuchsia bag'], [1, 3]]
# Children are: ['posh black bag', 'striped fuchsia bag']
# Amount is: [1, 3]
# Total bags inside : 12339
# New data is ['posh black bag', [], []]
# Data is: ['posh black bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 12339
# New data is ['striped fuchsia bag', ['posh lavender bag', 'dull cyan bag', 'posh black bag', 'vibrant bronze bag'], [4, 5, 2, 2]]
# Data is: ['striped fuchsia bag', ['posh lavender bag', 'dull cyan bag', 'posh black bag', 'vibrant bronze bag'], [4, 5, 2, 2]]
# Children are: ['posh lavender bag', 'dull cyan bag', 'posh black bag', 'vibrant bronze bag']
# Amount is: [4, 5, 2, 2]
# Total bags inside : 16239
# New data is ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Data is: ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Children are: ['bright red bag', 'shiny lime bag', 'bright chartreuse bag']
# Amount is: [3, 2, 2]
# Total bags inside : 24639
# New data is ['bright red bag', [], []]
# Data is: ['bright red bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 24639
# New data is ['shiny lime bag', [], []]
# Data is: ['shiny lime bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 24639
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 24639
# New data is ['dull cyan bag', [], []]
# Data is: ['dull cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 24639
# New data is ['posh black bag', [], []]
# Data is: ['posh black bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 24639
# New data is ['vibrant bronze bag', ['clear blue bag'], [5]]
# Data is: ['vibrant bronze bag', ['clear blue bag'], [5]]
# Children are: ['clear blue bag']
# Amount is: [5]
# Total bags inside : 27639
# New data is ['clear blue bag', [], []]
# Data is: ['clear blue bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 27639
# New data is ['bright maroon bag', [], []]
# Data is: ['bright maroon bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 27639
# New data is ['clear gray bag', ['bright red bag', 'dull cyan bag', 'bright maroon bag', 'muted gold bag'], [1, 2, 3, 3]]
# Data is: ['clear gray bag', ['bright red bag', 'dull cyan bag', 'bright maroon bag', 'muted gold bag'], [1, 2, 3, 3]]
# Children are: ['bright red bag', 'dull cyan bag', 'bright maroon bag', 'muted gold bag']
# Amount is: [1, 2, 3, 3]
# Total bags inside : 28089
# New data is ['bright red bag', [], []]
# Data is: ['bright red bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28089
# New data is ['dull cyan bag', [], []]
# Data is: ['dull cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28089
# New data is ['bright maroon bag', [], []]
# Data is: ['bright maroon bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28089
# New data is ['muted gold bag', [], []]
# Data is: ['muted gold bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28089
# New data is ['bright tomato bag', ['bright maroon bag', 'clear blue bag', 'posh lavender bag', 'shiny lime bag'], [3, 3, 5, 5]]
# Data is: ['bright tomato bag', ['bright maroon bag', 'clear blue bag', 'posh lavender bag', 'shiny lime bag'], [3, 3, 5, 5]]
# Children are: ['bright maroon bag', 'clear blue bag', 'posh lavender bag', 'shiny lime bag']
# Amount is: [3, 3, 5, 5]
# Total bags inside : 28329
# New data is ['bright maroon bag', [], []]
# Data is: ['bright maroon bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28329
# New data is ['clear blue bag', [], []]
# Data is: ['clear blue bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28329
# New data is ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Data is: ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Children are: ['bright red bag', 'shiny lime bag', 'bright chartreuse bag']
# Amount is: [3, 2, 2]
# Total bags inside : 28854
# New data is ['bright red bag', [], []]
# Data is: ['bright red bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28854
# New data is ['shiny lime bag', [], []]
# Data is: ['shiny lime bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28854
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28854
# New data is ['shiny lime bag', [], []]
# Data is: ['shiny lime bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28854
# New data is ['drab plum bag', ['vibrant bronze bag', 'muted olive bag', 'striped tan bag'], [5, 1, 1]]
# Data is: ['drab plum bag', ['vibrant bronze bag', 'muted olive bag', 'striped tan bag'], [5, 1, 1]]
# Children are: ['vibrant bronze bag', 'muted olive bag', 'striped tan bag']
# Amount is: [5, 1, 1]
# Total bags inside : 28861
# New data is ['vibrant bronze bag', ['clear blue bag'], [5]]
# Data is: ['vibrant bronze bag', ['clear blue bag'], [5]]
# Children are: ['clear blue bag']
# Amount is: [5]
# Total bags inside : 28886
# New data is ['clear blue bag', [], []]
# Data is: ['clear blue bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28886
# New data is ['muted olive bag', ['clear blue bag', 'posh lavender bag', 'posh brown bag', 'striped chartreuse bag'], [4, 1, 1, 2]]
# Data is: ['muted olive bag', ['clear blue bag', 'posh lavender bag', 'posh brown bag', 'striped chartreuse bag'], [4, 1, 1, 2]]
# Children are: ['clear blue bag', 'posh lavender bag', 'posh brown bag', 'striped chartreuse bag']
# Amount is: [4, 1, 1, 2]
# Total bags inside : 28894
# New data is ['clear blue bag', [], []]
# Data is: ['clear blue bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28894
# New data is ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Data is: ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Children are: ['bright red bag', 'shiny lime bag', 'bright chartreuse bag']
# Amount is: [3, 2, 2]
# Total bags inside : 28901
# New data is ['bright red bag', [], []]
# Data is: ['bright red bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28901
# New data is ['shiny lime bag', [], []]
# Data is: ['shiny lime bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28901
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28901
# New data is ['posh brown bag', ['dull cyan bag'], [3]]
# Data is: ['posh brown bag', ['dull cyan bag'], [3]]
# Children are: ['dull cyan bag']
# Amount is: [3]
# Total bags inside : 28904
# New data is ['dull cyan bag', [], []]
# Data is: ['dull cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28904
# New data is ['striped chartreuse bag', ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag'], [4, 1, 2]]
# Data is: ['striped chartreuse bag', ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag'], [4, 1, 2]]
# Children are: ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag']
# Amount is: [4, 1, 2]
# Total bags inside : 28918
# New data is ['posh black bag', [], []]
# Data is: ['posh black bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28918
# New data is ['vibrant cyan bag', [], []]
# Data is: ['vibrant cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28918
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28918
# New data is ['striped tan bag', ['mirrored olive bag', 'dark maroon bag'], [5, 4]]
# Data is: ['striped tan bag', ['mirrored olive bag', 'dark maroon bag'], [5, 4]]
# Children are: ['mirrored olive bag', 'dark maroon bag']
# Amount is: [5, 4]
# Total bags inside : 28927
# New data is ['mirrored olive bag', ['dull cyan bag', 'posh black bag', 'striped chartreuse bag'], [4, 4, 2]]
# Data is: ['mirrored olive bag', ['dull cyan bag', 'posh black bag', 'striped chartreuse bag'], [4, 4, 2]]
# Children are: ['dull cyan bag', 'posh black bag', 'striped chartreuse bag']
# Amount is: [4, 4, 2]
# Total bags inside : 28977
# New data is ['dull cyan bag', [], []]
# Data is: ['dull cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28977
# New data is ['posh black bag', [], []]
# Data is: ['posh black bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 28977
# New data is ['striped chartreuse bag', ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag'], [4, 1, 2]]
# Data is: ['striped chartreuse bag', ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag'], [4, 1, 2]]
# Children are: ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag']
# Amount is: [4, 1, 2]
# Total bags inside : 29047
# New data is ['posh black bag', [], []]
# Data is: ['posh black bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29047
# New data is ['vibrant cyan bag', [], []]
# Data is: ['vibrant cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29047
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29047
# New data is ['dark maroon bag', ['bright tomato bag', 'striped chartreuse bag', 'bright maroon bag'], [2, 2, 5]]
# Data is: ['dark maroon bag', ['bright tomato bag', 'striped chartreuse bag', 'bright maroon bag'], [2, 2, 5]]
# Children are: ['bright tomato bag', 'striped chartreuse bag', 'bright maroon bag']
# Amount is: [2, 2, 5]
# Total bags inside : 29083
# New data is ['bright tomato bag', ['bright maroon bag', 'clear blue bag', 'posh lavender bag', 'shiny lime bag'], [3, 3, 5, 5]]
# Data is: ['bright tomato bag', ['bright maroon bag', 'clear blue bag', 'posh lavender bag', 'shiny lime bag'], [3, 3, 5, 5]]
# Children are: ['bright maroon bag', 'clear blue bag', 'posh lavender bag', 'shiny lime bag']
# Amount is: [3, 3, 5, 5]
# Total bags inside : 29211
# New data is ['bright maroon bag', [], []]
# Data is: ['bright maroon bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29211
# New data is ['clear blue bag', [], []]
# Data is: ['clear blue bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29211
# New data is ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Data is: ['posh lavender bag', ['bright red bag', 'shiny lime bag', 'bright chartreuse bag'], [3, 2, 2]]
# Children are: ['bright red bag', 'shiny lime bag', 'bright chartreuse bag']
# Amount is: [3, 2, 2]
# Total bags inside : 29491
# New data is ['bright red bag', [], []]
# Data is: ['bright red bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29491
# New data is ['shiny lime bag', [], []]
# Data is: ['shiny lime bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29491
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29491
# New data is ['shiny lime bag', [], []]
# Data is: ['shiny lime bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29491
# New data is ['striped chartreuse bag', ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag'], [4, 1, 2]]
# Data is: ['striped chartreuse bag', ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag'], [4, 1, 2]]
# Children are: ['posh black bag', 'vibrant cyan bag', 'bright chartreuse bag']
# Amount is: [4, 1, 2]
# Total bags inside : 29547
# New data is ['posh black bag', [], []]
# Data is: ['posh black bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29547
# New data is ['vibrant cyan bag', [], []]
# Data is: ['vibrant cyan bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29547
# New data is ['bright chartreuse bag', [], []]
# Data is: ['bright chartreuse bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29547
# New data is ['bright maroon bag', [], []]
# Data is: ['bright maroon bag', [], []]
# Children are: []
# Amount is: []
# Total bags inside : 29547
# Starting to count all bags inside a 'shiny gold bag', for 570 families.
# The bags have been identified, split into 1188 datapoints.
# The amount of bags with a shiny gold bag inside, is 370!
# The amount of bags required inside a shiny gold bag is None
